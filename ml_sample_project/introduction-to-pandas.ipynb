# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "colours": colours})
car_data
# Out:
#   Car make colours
# 0      BMW     Red
# 1   Toyota    Blue
# 2    Honda   White

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
car_sales["Odometer (KM)"].std()
# Out:
# 61983.4717345412

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"], index=[1, 4, 3, 5, 3])

# %%
animals
# Out:
# 1      cat
# 4      dog
# 3     bird
# 5    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3     bird
# 3    snake
# dtype: object

# %%
animals.iloc[2]
# Out:
# 'bird'

# %%
animals.loc[3]
# Out:
# 3     bird
# 3    snake
# dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Manufactured Year"] = pd.Series([1827, 1987, 2001, 2002, 1999, 3872, "Blue", 2011])

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Manufactured Year  \
# 0  Toyota  White         150043      4   $4,000.00              1827
# 1   Honda    Red          87899      4   $5,000.00              1987
# 2  Toyota   Blue          32549      3   $7,000.00              2001
# 3     BMW  Black          11179      5  $22,000.00              2002
# 4  Nissan  White         213095      4   $3,500.00              1999
# 5  Toyota  Green          99213      4   $4,500.00              3872
# 6   Honda   Blue          45698      4   $7,500.00              Blue
# 7   Honda   Blue          54738      4   $7,000.00              2011
#
#    Price (USD)
# 0         4000
# 1         5000
# 2         7000
# 3        22000
# 4         3500
# 5         4500
# 6         7500
# 7         7000

# %%
car_sales["Price (VND)"] = car_sales["Price"] * 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Manufactured Year  \
# 0  Toyota  White         150043      4   $4,000.00              1827
# 1   Honda    Red          87899      4   $5,000.00              1987
# 2  Toyota   Blue          32549      3   $7,000.00              2001
# 3     BMW  Black          11179      5  $22,000.00              2002
# 4  Nissan  White         213095      4   $3,500.00              1999
# 5  Toyota  Green          99213      4   $4,500.00              3872
# 6   Honda   Blue          45698      4   $7,500.00              Blue
# 7   Honda   Blue          54738      4   $7,000.00              2011
# 8  Toyota  White          60000      4   $6,250.00               NaN
# 9  Nissan  White          31600      4   $9,700.00               NaN
#
#                                 Price (VND)
# 0      $4,000.00$4,000.00$4,000.00$4,000.00
# 1      $5,000.00$5,000.00$5,000.00$5,000.00
# 2      $7,000.00$7,000.00$7,000.00$7,000.00
# ...

# %%
car_sales.drop("Price (VND)", axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Manufactured Year
# 0  Toyota  White         150043      4   $4,000.00              1827
# 1   Honda    Red          87899      4   $5,000.00              1987
# 2  Toyota   Blue          32549      3   $7,000.00              2001
# 3     BMW  Black          11179      5  $22,000.00              2002
# 4  Nissan  White         213095      4   $3,500.00              1999
# 5  Toyota  Green          99213      4   $4,500.00              3872
# 6   Honda   Blue          45698      4   $7,500.00              Blue
# 7   Honda   Blue          54738      4   $7,000.00              2011
# 8  Toyota  White          60000      4   $6,250.00               NaN
# 9  Nissan  White          31600      4   $9,700.00               NaN

# %%
car_sales["Manufactured Year"].dropna(inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Manufactured Year
# 0  Toyota  White         150043      4   $4,000.00              1827
# 1   Honda    Red          87899      4   $5,000.00              1987
# 2  Toyota   Blue          32549      3   $7,000.00              2001
# 3     BMW  Black          11179      5  $22,000.00              2002
# 4  Nissan  White         213095      4   $3,500.00              1999
# 5  Toyota  Green          99213      4   $4,500.00              3872
# 6   Honda   Blue          45698      4   $7,500.00              Blue
# 7   Honda   Blue          54738      4   $7,000.00              2011
# 8  Toyota  White          60000      4   $6,250.00               NaN
# 9  Nissan  White          31600      4   $9,700.00               NaN

# %%
car_sales.dropna(inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Manufactured Year
# 0  Toyota  White         150043      4   $4,000.00              1827
# 1   Honda    Red          87899      4   $5,000.00              1987
# 2  Toyota   Blue          32549      3   $7,000.00              2001
# 3     BMW  Black          11179      5  $22,000.00              2002
# 4  Nissan  White         213095      4   $3,500.00              1999
# 5  Toyota  Green          99213      4   $4,500.00              3872
# 6   Honda   Blue          45698      4   $7,500.00              Blue
# 7   Honda   Blue          54738      4   $7,000.00              2011

# %%
import re  

str = "xyzd@gmail.com"
print(re.sub("^[a-z][a-z][a-z]", "abc", str))
# Out:
# abcd@gmail.com

# %%
str = "$6,250.00"
print(int(float(re.sub("[$,]", "", str))))
# Out:
# 6250

# %%
car_sales.drop('Price (USD)', axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Manufactured Year
# 0  Toyota  White         150043      4   $4,000.00              1827
# 1   Honda    Red          87899      4   $5,000.00              1987
# 2  Toyota   Blue          32549      3   $7,000.00              2001
# 3     BMW  Black          11179      5  $22,000.00              2002
# 4  Nissan  White         213095      4   $3,500.00              1999
# 5  Toyota  Green          99213      4   $4,500.00              3872
# 6   Honda   Blue          45698      4   $7,500.00              Blue
# 7   Honda   Blue          54738      4   $7,000.00              2011

# %%
car_sales["Price (USD)"] = car_sales["Price"].str.replace("[$,]", "", regex=True).astype(float).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Manufactured Year  \
# 0  Toyota  White         150043      4   $4,000.00              1827
# 1   Honda    Red          87899      4   $5,000.00              1987
# 2  Toyota   Blue          32549      3   $7,000.00              2001
# 3     BMW  Black          11179      5  $22,000.00              2002
# 4  Nissan  White         213095      4   $3,500.00              1999
# 5  Toyota  Green          99213      4   $4,500.00              3872
# 6   Honda   Blue          45698      4   $7,500.00              Blue
# 7   Honda   Blue          54738      4   $7,000.00              2011
#
#    Price (USD)
# 0         4000
# 1         5000
# 2         7000
# 3        22000
# 4         3500
# 5         4500
# 6         7500
# 7         7000

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price Manufactured Year  \
# 0  Toyota  White         150043      4  $4,000.00              1827
# 2  Toyota   Blue          32549      3  $7,000.00              2001
# 5  Toyota  Green          99213      4  $4,500.00              3872
#
#    Price (USD)
# 0         4000
# 2         7000
# 5         4500

# %%
car_sales["Avg Price"] = .mean(num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 car_sales["Make"].mean()
#
# File ~/Code/ml_sample_project/env/lib/python3.12/site-packages/pandas/core/series.py:6540, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6532 @doc(make_doc("mean", ndim=1))
#    6533 def mean(
#    6534     self,
#    (...)
#    6538     **kwargs,
#    6539 ):
# -> 6540     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/Code/ml_sample_project/env/lib/python3.12/site-packages/pandas/core/generic.py:12417, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# > 12417     return self._stat_function(
#   12418         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
# ...
